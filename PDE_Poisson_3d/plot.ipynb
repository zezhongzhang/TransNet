# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_pinn = pd.read_csv(f'pinn.csv')
print(df_pinn)

df_ls = pd.read_csv(f'ls.csv')
print(df_ls)
# Out:
#    basis_num  mse_final  mse_adam
# 0       1000   0.000113  0.062058
# 1       2000   0.000101  0.119990
# 2       3000   0.000246  0.153242
# 3       4000   0.000400  0.197043
# 4       5000   0.000800  0.230089
#    basis_num  mse_dnn_default  mse_pde_basis
# 0       1000         0.106415   4.773862e-01
# 1       2000         0.000767   2.624629e-05
# 2       3000         0.000112   1.684356e-06
# 3       4000         0.000035   4.343598e-08
# 4       5000         0.000015   1.495212e-09

# %%
plt.figure(figsize=(8,6))
plt.plot(df_ls['basis_num'], df_ls['mse_dnn_default'],'*-' ,label='dnn_default')
plt.plot(df_ls['basis_num'], df_ls['mse_pde_basis'],'*-' ,label='pde')

plt.plot(df_pinn['basis_num'], df_pinn['mse_final'],'*-', label='final_PINN')
plt.plot(df_pinn['basis_num'], df_pinn['mse_adam'],'*-', label='ADAM_PINN')
plt.yscale('log')
plt.legend()
plt.title('poisson_3d')
plt.grid(which='both')
plt.xlabel('Basis_num')
plt.ylabel('Test MSE')
plt.show()
