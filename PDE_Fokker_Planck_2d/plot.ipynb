# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_pinn = pd.read_csv(f'pinn.csv')
print(df_pinn)

df_ls = pd.read_csv(f'ls.csv')
print(df_ls)
# Out:
#    basis_num  mse_final  mse_adam
# 0       1000   0.000384  0.004484
# 1       2000   0.000592  0.007271
# 2       3000   0.000748  0.008444
# 3       4000   0.009283  0.009348
# 4       5000   0.010349  0.010396
#    basis_num  mse_dnn_default  mse_pde_basis
# 0       1000         0.000104   3.532710e-05
# 1       2000         0.000033   1.014528e-06
# 2       3000         0.000029   2.030686e-08
# 3       4000         0.000025   2.134975e-09
# 4       5000         0.000022   5.300730e-10

# %%
plt.figure(figsize=(8,6))
plt.plot(df_ls['basis_num'], df_ls['mse_dnn_default'],'*-' ,label='dnn_default')
plt.plot(df_ls['basis_num'], df_ls['mse_pde_basis'],'*-' ,label='pde')

plt.plot(df_pinn['basis_num'], df_pinn['mse_final'],'*-', label='final_PINN')
plt.plot(df_pinn['basis_num'], df_pinn['mse_adam'],'*-', label='ADAM_PINN')
plt.yscale('log')
plt.legend()
plt.title('Fokker Planck 2d')
plt.grid(which='both')
plt.xlabel('Basis_num')
plt.ylabel('Test MSE')
plt.show()
